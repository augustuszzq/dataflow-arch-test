# %%
import csv
import re

def convert_table_to_csv(input_file, output_file):
    with open(input_file, 'r', encoding='utf-8') as fin:
        lines = fin.readlines()

    rows = []
    for line in lines:
        line = line.strip()
        if line.startswith('|') and line.endswith('|'):
            if re.match(r'^\|[-+\s]+$', line):
                continue
            cells = [cell.strip() for cell in line.split('|')[1:-1]]
            if any(cells):
                rows.append(cells)

    with open(output_file, 'w', encoding='utf-8', newline='') as fout:
        writer = csv.writer(fout)
        for row in rows:
            writer.writerow(row)

convert_table_to_csv('/content/compile_report_20.txt', 'compile_report_20.csv')
convert_table_to_csv('/content/compile_report_19.txt', 'compile_report_19.csv')
convert_table_to_csv('/content/compile_report_18.txt', 'compile_report_18.csv')
convert_table_to_csv('/content/compile_report_17.txt', 'compile_report_17.csv')
convert_table_to_csv('/content/compile_report_16.txt', 'compile_report_15.csv')
convert_table_to_csv('/content/compile_report_15.txt', 'compile_report_16.csv')
convert_table_to_csv('/content/compile_report_14.txt', 'compile_report_14.csv')

# %%
import pandas as pd

df = pd.read_csv('compile_report_14.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_14_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_14_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_15.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_15_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_15_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_16.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_16_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_16_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_17.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_17_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_17_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_18.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_18_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_18_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_19.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_19_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_19_attention.csv', index=False)

# %%
df = pd.read_csv('compile_report_20.csv')

pattern = r'^(fc)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_20_fc.csv', index=False)

pattern = r'^(attention)\d+$'

filtered_df = df[df['Kernel Name'].str.match(pattern)]

filtered_df.to_csv('filtered_compile_report_20_attention.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('filtered_compile_report_14_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-16-ec33bb540dc7>:32: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-16-ec33bb540dc7>:32: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-16-ec33bb540dc7>:32: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-16-ec33bb540dc7>:32: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-16-ec33bb540dc7>:32: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('filtered_compile_report_14_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-4a89634566bb>:25: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-17-4a89634566bb>:25: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-17-4a89634566bb>:25: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-17-4a89634566bb>:25: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-17-4a89634566bb>:25: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_15_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_15_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-7038f0bcefca>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-18-7038f0bcefca>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-18-7038f0bcefca>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_16_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_16_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-c1d40ba3769c>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-19-c1d40ba3769c>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-19-c1d40ba3769c>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_17_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_17_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-20-093662140b76>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-20-093662140b76>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-20-093662140b76>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_18_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_18_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-21-0b9ad114c78e>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-21-0b9ad114c78e>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-21-0b9ad114c78e>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_19_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_19_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-22-0afc84511a87>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-22-0afc84511a87>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-22-0afc84511a87>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
df = pd.read_csv('filtered_compile_report_20_fc.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()


df = pd.read_csv('filtered_compile_report_20_attention.csv')

df['Samples/s'] = pd.to_numeric(df['Samples/s'], errors='coerce')
df['Active PEs'] = pd.to_numeric(df['Active PEs'], errors='coerce')
df['Compute Utilization'] = df['Compute Utilization'].str.rstrip('%')
df['Compute Utilization'] = pd.to_numeric(df['Compute Utilization'], errors='coerce')

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

axes[0].boxplot(df['Samples/s'].dropna())
axes[0].set_title('Samples/s')
axes[0].set_ylabel('数值')

axes[1].boxplot(df['Active PEs'].dropna())
axes[1].set_title('Active PEs')
axes[1].set_ylabel('数值')

axes[2].boxplot(df['Compute Utilization'].dropna())
axes[2].set_title('Compute Utilization (%)')
axes[2].set_ylabel('百分比')

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-c0520b2580da>:22: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:22: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:22: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:22: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:22: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# <ipython-input-26-c0520b2580da>:47: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:47: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:47: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:47: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# <ipython-input-26-c0520b2580da>:47: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 30334 (\N{CJK UNIFIED IDEOGRAPH-767E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 27604 (\N{CJK UNIFIED IDEOGRAPH-6BD4}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
